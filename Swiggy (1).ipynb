# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
df=pd.read_csv('Swiggy_Tax_file.csv')
df
# Out:
#        id                        payout_period  \
# 0    7551  23 February 2025 - 28 February 2025
# 1    7552  23 February 2025 - 28 February 2025
# 2    7553  23 February 2025 - 28 February 2025
# 3    7554  23 February 2025 - 28 February 2025
# 4    7555  23 February 2025 - 28 February 2025
# ..    ...                                  ...
# 96   7647        16 March 2025 - 22 March 2025
# 97   7648        09 March 2025 - 15 March 2025
# 98   7649        09 March 2025 - 15 March 2025
# 99   7650        16 March 2025 - 22 March 2025
# 100  7651        16 March 2025 - 22 March 2025
#
#                                              file_name       fy_year  year  \
# 0    _taco_Tax_Invoice_408_05032025_250305FS2900551...  FY_2024-2025  2025
# 1    _taco_Tax_Invoice_408_05032025_250305FS2900551...  FY_2024-2025  2025
# 2    _taco_Tax_Invoice_4780_05032025_250305FS290060...  FY_2024-2025  2025
# 3    _taco_Tax_Invoice_4780_05032025_250305FS290060...  FY_2024-2025  2025
# ...

# %%
df.head(5)
# Out:
#      id                        payout_period  \
# 0  7551  23 February 2025 - 28 February 2025
# 1  7552  23 February 2025 - 28 February 2025
# 2  7553  23 February 2025 - 28 February 2025
# 3  7554  23 February 2025 - 28 February 2025
# 4  7555  23 February 2025 - 28 February 2025
#
#                                            file_name       fy_year  year  \
# 0  _taco_Tax_Invoice_408_05032025_250305FS2900551...  FY_2024-2025  2025
# 1  _taco_Tax_Invoice_408_05032025_250305FS2900551...  FY_2024-2025  2025
# 2  _taco_Tax_Invoice_4780_05032025_250305FS290060...  FY_2024-2025  2025
# 3  _taco_Tax_Invoice_4780_05032025_250305FS290060...  FY_2024-2025  2025
# 4  _taco_Tax_Invoice_180801_05032025_250305FS2900...  FY_2024-2025  2025
#
#          month                                                irn  \
# 0  11_February  9610369c595615c3900981c25ae32b5875e5bd16c5d083...
# 1  11_February  9610369c595615c3900981c25ae32b5875e5bd16c5d083...
# ...

# %%
df.columns
# Out:
# Index(['id', 'payout_period', 'file_name', 'fy_year', 'year', 'month', 'irn',
#        'mann_gstin', 'swiggy_gstin', 'sr_no', 'description', 'hsn',
#        'unit_of_measure', 'quantity', 'unit_price', 'base_amount', 'discount',
#        'assessable_value', 'cgst_rate', 'cgst_amount', 'sgst_rate',
#        'sgst_amount', 'igst_rate', 'igst_amount', 'comp_cess_rate',
#        'comp_cess_amount', 'state_cess_rate', 'state_cess_amount',
#        'total_amount', 'other_charges_reimbursement_of_discount',
#        'grand_total', 'brand_id', 'pan', 'invoice_date', 'invoice_number',
#        'original_invoice_number', 'invoice_type', 'original_invoice_date'],
#       dtype='object')

# %%
df.rename(columns={'file_name':'f_name'},inplace=True)
df
# Out:
#        id                        payout_period  \
# 0    7551  23 February 2025 - 28 February 2025
# 1    7552  23 February 2025 - 28 February 2025
# 2    7553  23 February 2025 - 28 February 2025
# 3    7554  23 February 2025 - 28 February 2025
# 4    7555  23 February 2025 - 28 February 2025
# ..    ...                                  ...
# 96   7647        16 March 2025 - 22 March 2025
# 97   7648        09 March 2025 - 15 March 2025
# 98   7649        09 March 2025 - 15 March 2025
# 99   7650        16 March 2025 - 22 March 2025
# 100  7651        16 March 2025 - 22 March 2025
#
#                                                 f_name       fy_year  year  \
# 0    _taco_Tax_Invoice_408_05032025_250305FS2900551...  FY_2024-2025  2025
# 1    _taco_Tax_Invoice_408_05032025_250305FS2900551...  FY_2024-2025  2025
# 2    _taco_Tax_Invoice_4780_05032025_250305FS290060...  FY_2024-2025  2025
# 3    _taco_Tax_Invoice_4780_05032025_250305FS290060...  FY_2024-2025  2025
# ...

# %%
df.columns
# Out:
# Index(['id', 'payout_period', 'f_name', 'fy_year', 'year', 'month', 'irn',
#        'mann_gstin', 'swiggy_gstin', 'sr_no', 'description', 'hsn',
#        'unit_of_measure', 'quantity', 'unit_price', 'base_amount', 'discount',
#        'assessable_value', 'cgst_rate', 'cgst_amount', 'sgst_rate',
#        'sgst_amount', 'igst_rate', 'igst_amount', 'comp_cess_rate',
#        'comp_cess_amount', 'state_cess_rate', 'state_cess_amount',
#        'total_amount', 'other_charges_reimbursement_of_discount',
#        'grand_total', 'brand_id', 'pan', 'invoice_date', 'invoice_number',
#        'original_invoice_number', 'invoice_type', 'original_invoice_date'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# id                                           0
# payout_period                                0
# f_name                                       0
# fy_year                                      0
# year                                         0
# month                                        0
# irn                                          0
# mann_gstin                                   0
# swiggy_gstin                                 0
# sr_no                                        0
# description                                  0
# hsn                                          0
# unit_of_measure                              0
# quantity                                     0
# unit_price                                   0
# base_amount                                  0
# discount                                     0
# assessable_value                             0
# cgst_rate                                    0
# cgst_amount                                  0
# ...

# %%
mean_value=df["original_invoice_number"].mean()
mean_value
# Out:
# nan

# %%
df["original_invoice_number"].fillna(0)
print(df)
# Out:
#        id                        payout_period  \
# 0    7551  23 February 2025 - 28 February 2025
# 1    7552  23 February 2025 - 28 February 2025
# 2    7553  23 February 2025 - 28 February 2025
# 3    7554  23 February 2025 - 28 February 2025
# 4    7555  23 February 2025 - 28 February 2025
# ..    ...                                  ...
# 96   7647        16 March 2025 - 22 March 2025
# 97   7648        09 March 2025 - 15 March 2025
# 98   7649        09 March 2025 - 15 March 2025
# 99   7650        16 March 2025 - 22 March 2025
# 100  7651        16 March 2025 - 22 March 2025
#
#                                                 f_name       fy_year  year  \
# 0    _taco_Tax_Invoice_408_05032025_250305FS2900551...  FY_2024-2025  2025
# 1    _taco_Tax_Invoice_408_05032025_250305FS2900551...  FY_2024-2025  2025
# 2    _taco_Tax_Invoice_4780_05032025_250305FS290060...  FY_2024-2025  2025
# 3    _taco_Tax_Invoice_4780_05032025_250305FS290060...  FY_2024-2025  2025
# ...

# %%
df1=df.dropna(subset=["original_invoice_number"])
df1.isnull().sum()
# Out:
# id                                         0.0
# payout_period                              0.0
# f_name                                     0.0
# fy_year                                    0.0
# year                                       0.0
# month                                      0.0
# irn                                        0.0
# mann_gstin                                 0.0
# swiggy_gstin                               0.0
# sr_no                                      0.0
# description                                0.0
# hsn                                        0.0
# unit_of_measure                            0.0
# quantity                                   0.0
# unit_price                                 0.0
# base_amount                                0.0
# discount                                   0.0
# assessable_value                           0.0
# cgst_rate                                  0.0
# cgst_amount                                0.0
# ...

# %%
df1.isnull().sum()
# Out:
# id                                         0.0
# payout_period                              0.0
# f_name                                     0.0
# fy_year                                    0.0
# year                                       0.0
# month                                      0.0
# irn                                        0.0
# mann_gstin                                 0.0
# swiggy_gstin                               0.0
# sr_no                                      0.0
# description                                0.0
# hsn                                        0.0
# unit_of_measure                            0.0
# quantity                                   0.0
# unit_price                                 0.0
# base_amount                                0.0
# discount                                   0.0
# assessable_value                           0.0
# cgst_rate                                  0.0
# cgst_amount                                0.0
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 38 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   id                                       0 non-null      int64
#  1   payout_period                            0 non-null      object
#  2   f_name                                   0 non-null      object
#  3   fy_year                                  0 non-null      object
#  4   year                                     0 non-null      int64
#  5   month                                    0 non-null      object
#  6   irn                                      0 non-null      object
#  7   mann_gstin                               0 non-null      object
#  8   swiggy_gstin                             0 non-null      object
#  9   sr_no                                    0 non-null      int64
# ...

# %%
df1.groupby('invoice_type')['invoice_type'].agg("count")
# Out:
# Series([], Name: invoice_type, dtype: int64)

# %%
df1["invoice_type"].unique()
# Out:
# array([], dtype=object)

# %%
import matplotlib.pyplot as plt
plt.xlabel('sr_no')
plt.ylabel('quantity')
plt.title('Graph for outliers')
plt.grid(True)
 
plt.show()
